# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2022/view/espnu150/order/true'

r = requests.get(url).text
soup = BeautifulSoup(r, 'lxml')
data = pd.read_html(str(soup.table))[0] 
data['YEAR'] = 2022#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2021/view/espnu150/order/true'

r2 = requests.get(url).text
soup2 = BeautifulSoup(r2, 'lxml')
data2 = pd.read_html(str(soup2.table))[0]
data2['YEAR'] = 2021#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2020/view/espnu150/order/true'

r3 = requests.get(url).text
soup3 = BeautifulSoup(r3, 'lxml')
data3 = pd.read_html(str(soup3.table))[0]
data3['YEAR'] = 2020#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2019/view/espnu150/order/true'

r4 = requests.get(url).text
soup4 = BeautifulSoup(r4, 'lxml')
data4 = pd.read_html(str(soup4.table))[0]
data4['YEAR'] = 2019#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2018/view/espnu150/order/true'

r5 = requests.get(url).text
soup5 = BeautifulSoup(r5, 'lxml')
data5 = pd.read_html(str(soup5.table))[0]
data5['YEAR'] = 2018#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2017/view/espnu150/order/true'

r6 = requests.get(url).text
soup6 = BeautifulSoup(r6, 'lxml')
data6 = pd.read_html(str(soup6.table))[0]
data6['YEAR'] = 2017#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2016/view/espnu150/order/true'

r7 = requests.get(url).text
soup7 = BeautifulSoup(r7, 'lxml')
data7 = pd.read_html(str(soup7.table))[0]
data7['YEAR'] = 2016#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2015/view/espnu150/order/true'

r8 = requests.get(url).text
soup8 = BeautifulSoup(r8, 'lxml')
data8 = pd.read_html(str(soup8.table))[0]
data8['YEAR'] = 2015#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2014/view/espnu150/order/true'

r9 = requests.get(url).text
soup9 = BeautifulSoup(r9, 'lxml')
data9 = pd.read_html(str(soup9.table))[0]
data9['YEAR'] = 2014#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2013/view/espnu150/order/true'

r10 = requests.get(url).text
soup10 = BeautifulSoup(r10, 'lxml')
data10 = pd.read_html(str(soup10.table))[0]
data10['YEAR'] = 2013#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2012/view/espnu150/order/true'

r11 = requests.get(url).text
soup11 = BeautifulSoup(r11, 'lxml')
data11 = pd.read_html(str(soup11.table))[0]
data11['YEAR'] = 2012#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2011/view/espnu150/order/true'

r12 = requests.get(url).text
soup12 = BeautifulSoup(r12, 'lxml')
data12 = pd.read_html(str(soup12.table))[0]
data12['YEAR'] = 2011#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2010/view/espnu150/order/true'

r13 = requests.get(url).text
soup13 = BeautifulSoup(r13, 'lxml')
data13 = pd.read_html(str(soup13.table))[0]
data13['YEAR'] = 2010#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2009/view/espnu150/order/true'

r14 = requests.get(url).text
soup14 = BeautifulSoup(r14, 'lxml')
data14 = pd.read_html(str(soup14.table))[0]
data14['YEAR'] = 2009#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2008/view/espnu150/order/true'

r15 = requests.get(url).text
soup15 = BeautifulSoup(r15, 'lxml')
data15 = pd.read_html(str(soup15.table))[0]
data15['YEAR'] = 2008#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2007/view/espnu150/order/true'

r16 = requests.get(url).text
soup16 = BeautifulSoup(r16, 'lxml')
data16 = pd.read_html(str(soup16.table))[0]
data16['YEAR'] = 2007#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2006/view/espnu150/order/true'

r17 = requests.get(url).text
soup17 = BeautifulSoup(r17, 'lxml')
data17 = pd.read_html(str(soup17.table))[0]
data17['YEAR'] = 2006#[-21:-25]




rank = pd.concat([data, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16, data17], ignore_index = True)

#stats.append(data, data2)  
#stats = pd.concat(stats)


print(rank.shape)
rank.head()

rank.to_excel(r'C:\Gilles\Data\E150.xlsx')

#print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-60fb2a002625> in <module>
#      28 r4 = requests.get(url).text
#      29 soup4 = BeautifulSoup(r4, 'lxml')
# ---> 30 data4 = pd.read_html(str(soup4.table))[0]
#      31 data4['YEAR'] = 2019#[-21:-25]
#      32
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
# ...

# %%
url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2022/view/espnu150/order/true'

r = requests.get(url).text
soup = BeautifulSoup(r, 'lxml')
data = pd.read_html(str(soup.table))[0] 
data['YEAR'] = 2022#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2021/view/espnu150/order/true'

r2 = requests.get(url).text
soup2 = BeautifulSoup(r2, 'lxml')
data2 = pd.read_html(str(soup2.table))[0]
data2['YEAR'] = 2021#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2020/view/espnu150/order/true'

r3 = requests.get(url).text
soup3 = BeautifulSoup(r3, 'lxml')
data3 = pd.read_html(str(soup3.table))[0]
data3['YEAR'] = 2020#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2019/view/espnu150/order/true'

r4 = requests.get(url).text
soup4 = BeautifulSoup(r4, 'lxml')
data4 = pd.read_html(str(soup4.table))[0]
data4['YEAR'] = 2019#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2018/view/espnu150/order/true'

r5 = requests.get(url).text
soup5 = BeautifulSoup(r5, 'lxml')
data5 = pd.read_html(str(soup5.table))[0]
data5['YEAR'] = 2018#[-21:-25]

rank = pd.concat([data, data2, data3, data4, data5], ignore_index = True)

#stats.append(data, data2)  
#stats = pd.concat(stats)


print(rank.shape)
rank.head()
# Out:
# (755, 10)
#     0                                    1      2  \
# 0  RK                               PLAYER    POS
# 1   1     Quinn EwersVideo | Scouts Report  QB-PP
# 2   2    Walter NolenVideo | Scouts Report     DT
# 3   3  Shemar StewartVideo | Scouts Report     DE
# 4   4    Aaron WilsonVideo | Scouts Report     DE
#
#                                             3      4    5      6      7  \
# 0                                    HOMETOWN     HT   WT  STARS  GRADE
# 1            Southlake, TXCarroll High School  6'3''  205    NaN     92
# 2            Cordova, TNSaint Benedict School  6'3''  300    NaN     91
# 3  Miami, FLMonsignor Edward Pace High School  6'5''  235    NaN     91
# 4            Baltimore, MDSt. Frances Academy  6'2''  235    NaN     90
#
#                           8  YEAR
# 0                    SCHOOL  2022
# 1  TexasCommitted08/14/2020  2022
# 2                      List  2022
# 3                      List  2022
# 4                      List  2022

# %%
url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2017/view/espnu150/order/true'

r6 = requests.get(url).text
soup6 = BeautifulSoup(r6, 'lxml')
data6 = pd.read_html(str(soup6.table))[0]
data6['YEAR'] = 2017#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2016/view/espnu150/order/true'

r7 = requests.get(url).text
soup7 = BeautifulSoup(r7, 'lxml')
data7 = pd.read_html(str(soup7.table))[0]
data7['YEAR'] = 2016#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2015/view/espnu150/order/true'

r8 = requests.get(url).text
soup8 = BeautifulSoup(r8, 'lxml')
data8 = pd.read_html(str(soup8.table))[0]
data8['YEAR'] = 2015#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2014/view/espnu150/order/true'

r9 = requests.get(url).text
soup9 = BeautifulSoup(r9, 'lxml')
data9 = pd.read_html(str(soup9.table))[0]
data9['YEAR'] = 2014#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2013/view/espnu150/order/true'

r10 = requests.get(url).text
soup10 = BeautifulSoup(r10, 'lxml')
data10 = pd.read_html(str(soup10.table))[0]
data10['YEAR'] = 2013#[-21:-25]

rank2 = pd.concat([data6, data7, data8, data9, data10], ignore_index = True)

#stats.append(data, data2)  
#stats = pd.concat(stats)


print(rank2.shape)
rank2.head()
# Out:
# (755, 10)
#     0                                     1    2  \
# 0  RK                                PLAYER  POS
# 1   1       Trey SmithVideo | Scouts Report   OT
# 2   2    Isaiah WilsonVideo | Scouts Report   OT
# 3   3  Jaelan PhillipsVideo | Scouts Report  OLB
# 4   4    Marvin WilsonVideo | Scouts Report   DT
#
#                                               3      4    5      6      7  \
# 0                                      HOMETOWN     HT   WT  STARS  GRADE
# 1       Jackson, TNUniversity School of Jackson  6'6''  299    NaN     93
# 2      Brooklyn, NYPoly Prep Country Day School  6'7''  354    NaN     93
# 3  Redlands, CARedlands East Valley High School  6'5''  241    NaN     93
# 4              Houston, TXEpiscopal High School  6'4''  332    NaN     92
#
#                   8  YEAR
# 0            SCHOOL  2017
# 1   TennesseeSigned  2017
# 2     GeorgiaSigned  2017
# 3        UCLASigned  2017
# 4  Florida StSigned  2017

# %%
url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2012/view/espnu150/order/true'

r11 = requests.get(url).text
soup11 = BeautifulSoup(r11, 'lxml')
data11 = pd.read_html(str(soup11.table))[0]
data11['YEAR'] = 2012#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2011/view/espnu150/order/true'

r12 = requests.get(url).text
soup12 = BeautifulSoup(r12, 'lxml')
data12 = pd.read_html(str(soup12.table))[0]
data12['YEAR'] = 2011#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2010/view/espnu150/order/true'

r13 = requests.get(url).text
soup13 = BeautifulSoup(r13, 'lxml')
data13 = pd.read_html(str(soup13.table))[0]
data13['YEAR'] = 2010#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2009/view/espnu150/order/true'

r14 = requests.get(url).text
soup14 = BeautifulSoup(r14, 'lxml')
data14 = pd.read_html(str(soup14.table))[0]
data14['YEAR'] = 2009#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2008/view/espnu150/order/true'

r15 = requests.get(url).text
soup15 = BeautifulSoup(r15, 'lxml')
data15 = pd.read_html(str(soup15.table))[0]
data15['YEAR'] = 2008#[-21:-25]

rank3 = pd.concat([data11, data12, data13, data14, data15], ignore_index = True)

#stats.append(data, data2)  
#stats = pd.concat(stats)


print(rank3.shape)
rank3.head()
# Out:
# (755, 10)
#     0                                          1    2  \
# 0  RK                                     PLAYER  POS
# 1   1         Mario EdwardsVideo | Scouts Report   DE
# 2   2        Johnathan GrayVideo | Scouts Report   RB
# 3   3  Dorial Green-BeckhamVideo | Scouts Report   WR
# 4   4           Noah SpenceVideo | Scouts Report   DE
#
#                                            3       4    5      6      7  \
# 0                                   HOMETOWN      HT   WT  STARS  GRADE
# 1           Denton, TXBilly Ryan High School   6'4''  297    NaN     90
# 2                 Aledo, TXAledo High School  5'10''  205    NaN     86
# 3       Springfield, MOHillcrest High School   6'6''  220    NaN     86
# 4  Harrisburg, PABishop McDevitt High School   6'4''  245    NaN     86
#
#                   8  YEAR
# 0            SCHOOL  2012
# 1  Florida StSigned  2012
# 2       TexasSigned  2012
# 3    MissouriSigned  2012
# 4  Ohio StateSigned  2012

# %%
url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2007/view/espnu150/order/true'

r16 = requests.get(url).text
soup16 = BeautifulSoup(r16, 'lxml')
data16 = pd.read_html(str(soup16.table))[0]
data16['YEAR'] = 2007#[-21:-25]

url = 'http://www.espn.com/college-sports/football/recruiting/playerrankings/_/class/2006/view/espnu150/order/true'

r17 = requests.get(url).text
soup17 = BeautifulSoup(r17, 'lxml')
data17 = pd.read_html(str(soup17.table))[0]
data17['YEAR'] = 2006#[-21:-25]

rank4 = pd.concat([data16, data17], ignore_index = True)

#stats.append(data, data2)  
#stats = pd.concat(stats)


print(rank4.shape)
rank4.head()
# Out:
# (302, 10)
#     0                                   1    2  \
# 0  RK                              PLAYER  POS
# 1   1   Joe McKnightVideo | Scouts Report   RB
# 2   2  Chris GalippoVideo | Scouts Report  ILB
# 3   3     Marc TylerVideo | Scouts Report   RB
# 4   4     Eric BerryVideo | Scouts Report   CB
#
#                                                   3       4    5      6  \
# 0                                          HOMETOWN      HT   WT  STARS
# 1  River Ridge, LAJohn Curtis Christian High School   6'0''  190    NaN
# 2                    Anaheim, CAServite High School   6'2''  240    NaN
# 3    Westlake Village, CAOaks Christian High School   6'1''  210    NaN
# 4                 Fairburn, GACreekside High School  5'11''  195    NaN
#
#        7                8  YEAR
# 0  GRADE           SCHOOL  2007
# 1     92        USCSigned  2007
# 2     90        USCSigned  2007
# 3     90        USCSigned  2007
# 4     90  TennesseeSigned  2007

# %%
print(soup.table)
# Out:
# <table cellpadding="0" cellspacing="0" width="100%"><tr class="colhead"><td width="3%">RK</td><td width="25%">PLAYER</td><td width="6%">POS</td><td width="20%">HOMETOWN</td><td width="5%">HT</td><td width="5%">WT</td><td width="10%">STARS</td><td width="3%">GRADE</td><td width="23%">SCHOOL</td></tr><!--RF:show gradetrue--><tr class="oddrow player-3540-240090"><td class="sortcell" style="color:#8a8a8a;font-weight:bold;text-align:center;vertical-align:middle; font-size:21px;">1</td><td><div class="name"><a href="http://www.espn.com/college-sports/football/recruiting/player/_/id/240090/quinn-ewers"><strong>Quinn Ewers</strong></a><br/><span>Video | <a href="http://insider.espn.com/college-sports/football/recruiting/player/evaluation/_/id/240090/quinn-ewers">Scouts Report</a></span><br/><!--SMR: rank is 1--><a href="http://www.espn.com/college-sports/football/recruiting/playerrankings/_/view/rn300jr/sort/rank/class/2022"><img border="0" class="floatleft" src="https://a.espncdn.com/i/recr
# ...

# %%
data = pd.read_html(str(soup.table))[0] 

print(data.shape)
data.head()
# Out:
# (151, 9)
#     0                                    1      2  \
# 0  RK                               PLAYER    POS
# 1   1     Quinn EwersVideo | Scouts Report  QB-PP
# 2   2    Walter NolenVideo | Scouts Report     DT
# 3   3  Shemar StewartVideo | Scouts Report     DE
# 4   4    Aaron WilsonVideo | Scouts Report     DE
#
#                                             3      4    5      6      7  \
# 0                                    HOMETOWN     HT   WT  STARS  GRADE
# 1            Southlake, TXCarroll High School  6'3''  205    NaN     92
# 2            Cordova, TNSaint Benedict School  6'3''  300    NaN     91
# 3  Miami, FLMonsignor Edward Pace High School  6'5''  235    NaN     91
# 4            Baltimore, MDSt. Frances Academy  6'2''  235    NaN     90
#
#                           8
# 0                    SCHOOL
# 1  TexasCommitted08/14/2020
# 2                      List
# 3                      List
# 4                      List

# %%
for link in soup.find_all("a"):
    print("Inner Text: {}".format(link.text))
    print("Title: {}".format(link.get("title")))
    print("href: {}".format(link.get("href")))
# Out:
# Inner Text: Back to Ranking Index
# Title: None
# href: http://www.espn.com/college-sports/football/recruiting/rankings
# Inner Text: Quinn Ewers
# Title: None
# href: http://www.espn.com/college-sports/football/recruiting/player/_/id/240090/quinn-ewers
# Inner Text: Scouts Report
# Title: None
# href: http://insider.espn.com/college-sports/football/recruiting/player/evaluation/_/id/240090/quinn-ewers
# Inner Text:
# Title: None
# href: http://www.espn.com/college-sports/football/recruiting/playerrankings/_/view/rn300jr/sort/rank/class/2022
# Inner Text:
# Title: None
# href: http://www.espn.com/college-sports/football/recruiting/school/_/id/251/class/2022/texas-longhorns
# Inner Text: Walter Nolen
# Title: None
# href: http://www.espn.com/college-sports/football/recruiting/player/_/id/240611/walter-nolen
# Inner Text: Scouts Report
# Title: None
# href: http://insider.espn.com/college-sports/football/recruiting/player/evaluation/_/id/240611/walter-nolen
# Inner Text:
# Title: None
# ...

# %%
E150 = pd.concat([rank, rank2, rank3, rank4], ignore_index = True)

E150.to_excel(r'C:\Gilles\Data\E150.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5004fc78ec2> in <module>
# ----> 1 E150 = pd.concat([rank, rank2, rank3, rank4], ignore_index = True)
#       2
#       3 E150.to_excel(r'C:\Gilles\Data\E150.xlsx')
#
# NameError: name 'pd' is not defined
